# %% [markdown]
# <a href="https://colab.research.google.com/github/Siamese001/Gemini-Prompts/blob/main/Resume_Generator.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
from google.colab import userdata

# Ensure the API key is in the environment for the subprocess
os.environ['GEMINI_API_KEY'] = userdata.get('GEMINI_API_KEY')

# Set the correct path to the master resume file as an environment variable.
os.environ['MASTER_RESUME_PATH'] = '/content/Resume Generator - Old/master_resume.json'

# Run the script using the full path to the latest version in the specified folder.
# !python "/content/Resume Generator - Old/Resume_Generation_v15_65.py"
# Out:
# ...
# Starting Resume Generation for: DataDog - Director, Technology Alliances
# ...
#
# 2025-10-29 19:33:55,118 - __main__ - INFO - setup_workflow_logging:181 - [b502e044] - H0_INFO - Workflow logging initialized. ID: b502e044, Log file: resume_generation_20251029_193355.log
# 2025-10-29 19:33:55,118 - __main__ - INFO - __init__:7479 - [b502e044] - H0_INFO - Workflow initialized. ID: b502e044
# 2025-10-29 19:33:55,118 - __main__ - INFO - __init__:7480 - [b502e044] - H0_INFO - Test mode: False
# 2025-10-29 19:33:55,118 - __main__ - INFO - __init__:7481 - [b502e044] - H0_INFO - Log file: resume_generation_20251029_193355.log
# 2025-10-29 19:33:55,119 - __main__ - INFO - __init__:7513 - [b502e044] - ✓ GEMINI_API_KEY detected and configured - Gemini API integration enabled
# 2025-10-29 19:33:55,119 - __main__ - INFO - __init__:7519 - [b502e044] - Using LLM Provider: Gemini
# 2025-10-29 19:33:55,119 - __main__ - INFO - __init__:7520 - [b502e044] - Using Model: gemini-2.5-pro
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive
